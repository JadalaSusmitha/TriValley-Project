# %%
#Code snippet 0
#installing the pycaret auto ML package
# !pip install -U --pre pycaret

# %%
#code snippet 1
#importing the pandas package to process dataset and displaying the data
import pandas as pd
data=pd.read_csv('https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/Trivalley%20Customer%20Spend%20and%20Buyer%20Flag%20Data.csv')
data
# Out:
#        CustomerID  AveMonthSpend  BikeBuyer Title  FirstName MiddleName  \
# 0           11000             89          0   NaN        Jon          V
# 1           11001            117          1   NaN     Eugene          L
# 2           11002            123          0   NaN      Ruben        NaN
# 3           11003             50          0   NaN    Christy        NaN
# 4           11004             95          1   NaN  Elizabeth        NaN
# ...           ...            ...        ...   ...        ...        ...
# 16514       13121            101          0   NaN    Latasha          E
# 16515       26100             46          0   NaN      James     Garner
# 16516       11328             79          0   NaN     Julian          M
# 16517       23077             65          0   NaN     Marvin          A
# 16518       18982             68          0   NaN       Kyle        NaN
#
#          LastName Suffix         AddressLine1 AddressLine2  ...   BirthDate  \
# ...

# %%
#code snippet 2
#displaying the dataset columns
data.columns
# Out:
# Index(['CustomerID', 'AveMonthSpend', 'BikeBuyer', 'Title', 'FirstName',
#        'MiddleName', 'LastName', 'Suffix', 'AddressLine1', 'AddressLine2',
#        'City', 'StateProvinceName', 'CountryRegionName', 'PostalCode',
#        'PhoneNumber', 'BirthDate', 'Education', 'Occupation', 'Gender',
#        'MaritalStatus', 'HomeOwnerFlag', 'NumberCarsOwned',
#        'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome'],
#       dtype='object')

# %%
#code snippet 3
#setting the dependent variable
y1='AveMonthSpend'

# %%
#code snippet 4
#settting the ignored columns(noise variables and variables that are missing the 20% data)
ignored_cols=['Title','MiddleName','Suffix','AddressLine2','CustomerID','FirstName','LastName','AddressLine1','PhoneNumber','BirthDate','Education','HomeOwnerFlag','BikeBuyer']

# %%
#code snippet 5
#setting the categorical columns
cat_cols=['City', 'StateProvinceName', 'CountryRegionName', 'PostalCode',
         'Occupation', 'Gender','MaritalStatus']

# %%
#code snippet 6
#setting the numerical columns
num_cols=[ 'NumberCarsOwned',
       'NumberChildrenAtHome', 'TotalChildren', 'YearlyIncome']

# %%
# code snippet 7
#importing the pycaret regression components
from pycaret.regression import*

# %%
#code snippet 8
#setting/configuring the ML model experiment with pycaret
regression_model_setup=setup(data,
                             target=y1,
                             categorical_features=cat_cols,
                             numeric_features=num_cols,
                             ignore_features=ignored_cols)
# Out:
# <style type="text/css">
# #T_83546_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_83546" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_83546_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_83546_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_83546_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_83546_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_83546_row0_col1" class="data row0 col1" >3478</td>
#     </tr>
#     <tr>
#       <th id="T_83546_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_83546_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_83546_row1_col1" class="data row1 col1" >AveMonthSpend</td>
#     </tr>
#     <tr>
#       <th id="T_83546_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
#code snippet 9
# Invoking the ML algorithm
compare_models()
# Out:
# <style type="text/css">
# #T_a7563 th {
#   text-align: left;
# }
# ...

# %%
#code snippet 10
#building the model with best algorithm
model=create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_d193e_row10_col0, #T_d193e_row10_col1, #T_d193e_row10_col2, #T_d193e_row10_col3, #T_d193e_row10_col4, #T_d193e_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d193e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d193e_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d193e_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d193e_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d193e_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d193e_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d193e_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %%
#code snippet 11
#importing the client_data(which is used to predict AveMonthSpend)
client_data=pd.read_csv(' https://raw.githubusercontent.com/nvamsimohan/DallasDSA/main/Trivalley%20Client%20data%20file.csv')
client_data
# Out:
#        CustomerID           City StateProvinceName CountryRegionName  \
# 0           58772        Seaford          Victoria         Australia
# 1           98594     North Ryde   New South Wales         Australia
# 2           96960     Wollongong   New South Wales         Australia
# 3           72891  East Brisbane        Queensland         Australia
# 4           74195    Warrnambool          Victoria         Australia
# ...           ...            ...               ...               ...
# 13188       55020        Sunbury          Victoria         Australia
# 13189       77277         Melton          Victoria         Australia
# 13190       96565        Shawnee  British Columbia            Canada
# 13191       79375         Rhodes   New South Wales         Australia
# 13192       52536       Kirkland        Washington     United States
#
#       PostalCode   BirthDate        Education      Occupation Gender  \
# ...

# %%
#code snippet 12
#prdicting the avemonthspend using the ML model
client_data_predictions = predict_model(model, client_data)

#displaying the predictions
client_data_predictions
# Out:
#        CustomerID           City StateProvinceName CountryRegionName  \
# 0           58772        Seaford          Victoria         Australia
# 1           98594     North Ryde   New South Wales         Australia
# 2           96960     Wollongong   New South Wales         Australia
# 3           72891  East Brisbane        Queensland         Australia
# 4           74195    Warrnambool          Victoria         Australia
# ...           ...            ...               ...               ...
# 13188       55020        Sunbury          Victoria         Australia
# 13189       77277         Melton          Victoria         Australia
# 13190       96565        Shawnee  British Columbia            Canada
# 13191       79375         Rhodes   New South Wales         Australia
# 13192       52536       Kirkland        Washington     United States
#
#       PostalCode   BirthDate        Education      Occupation Gender  \
# ...

# %%
#code snippet 13
#exporting the predictions to a csv file
client_data_predictions.to_csv('Trivalley Bike Store client data Predictions.csv')
